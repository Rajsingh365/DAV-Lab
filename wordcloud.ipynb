# %%
text = '''
  hello hello world hi hi hello
'''

# %%
# %pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\raj singh\documents\semester exams\sem 6\dav\coding\dav_venv\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\raj singh\documents\semester exams\sem 6\dav\coding\dav_venv\lib\site-packages (from wordcloud) (2.2.5)
# Requirement already satisfied: pillow in c:\users\raj singh\documents\semester exams\sem 6\dav\coding\dav_venv\lib\site-packages (from wordcloud) (11.2.1)
# Requirement already satisfied: matplotlib in c:\users\raj singh\documents\semester exams\sem 6\dav\coding\dav_venv\lib\site-packages (from wordcloud) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\raj singh\documents\semester exams\sem 6\dav\coding\dav_venv\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\raj singh\documents\semester exams\sem 6\dav\coding\dav_venv\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\raj singh\documents\semester exams\sem 6\dav\coding\dav_venv\lib\site-packages (from matplotlib->wordcloud) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\raj singh\documents\semester exams\sem 6\dav\coding\dav_venv\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\raj singh\documents\semester exams\sem 6\dav\coding\dav_venv\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\raj singh\documents\semester exams\sem 6\dav\coding\dav_venv\lib\site-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\raj singh\documents\semester exams\sem 6\dav\coding\dav_venv\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\raj singh\documents\semester exams\sem 6\dav\coding\dav_venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(background_color='white').generate(text)

print(wordcloud.process_text(text))


plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# {'hello': 3, 'world': 1, 'hi': 2}
