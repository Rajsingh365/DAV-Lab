# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load dataset
df=pd.read_csv('Datasets/Iris.csv')
df.drop(columns=['Id'], inplace=True)
df.sample(5)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 129            7.2           3.0            5.8           1.6   Iris-virginica
# 62             6.0           2.2            4.0           1.0  Iris-versicolor
# 64             5.6           2.9            3.6           1.3  Iris-versicolor
# 24             4.8           3.4            1.9           0.2      Iris-setosa
# 76             6.8           2.8            4.8           1.4  Iris-versicolor

# %%
#1. Line Plot
plt.plot(df['SepalLengthCm'])
plt.title("Sepal Length in Cm")
# Out:
# Text(0.5, 1.0, 'Sepal Length in Cm')

# %%
plt.scatter(df['PetalLengthCm'], df['PetalWidthCm'])

# %%
freq=df['Species'].value_counts()
plt.bar(df['Species'].unique(), freq)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie(freq, autopct="%1.1f", labels=df['Species'].unique())
# Out:
# ([<matplotlib.patches.Wedge at 0x15638b3c110>,
# ...
#  [Text(0.5499999722395388, 0.9526279601903919, 'Iris-setosa'),
#   Text(-1.0999999999999959, -9.616505800409723e-08, 'Iris-versicolor'),
#   Text(0.5500003659264656, -0.9526277328950455, 'Iris-virginica')],
#  [Text(0.29999998485793017, 0.5196152510129409, '33.3'),
#   Text(-0.5999999999999978, -5.2453668002234845e-08, '33.3'),
#   Text(0.3000001995962539, -0.5196151270336611, '33.3')])

# %%
plt.boxplot([df['PetalLengthCm'], df['PetalWidthCm']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x156389e6550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x15638a02590>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x15638a00cd0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x15638a03810>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x15638a0c090>,
# ...
#  'means': []}

# %%
plt.hist(df['PetalLengthCm'])
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)

# %%
fig, axes = plt.subplots(5, 1, sharex = False)

# 1. Line plot
axes[0].plot(X[:, 0])
axes[0].set_xlabel("Sepal length")

# 2. Scatter plot
axes[1].scatter(X[:, 0], X[:, 1])

# 3. Bar plot
axes[2].bar([0, 1, 2], [sum(y==0), sum(y==1), sum(y==2)])

# 4. Histogram
axes[3].hist(X[:, 0], bins=20)

# 5. Box plot
axes[4].boxplot(X[:, 0])

plt.show()
